# %%
# !pip install depmap_downloader
# Out:
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [depmap_downloader]0m 12/13 [depmap_downloader]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
import seaborn as sns
import pandas as pd
from depmap_downloader import ensure_achilles_gene_dependencies, ensure_crispr_gene_dependencies, ensure_rnai_gene_dependencies

# %%
crsgenedf = pd.read_csv('../data/CRISPRGeneDependency.csv')
